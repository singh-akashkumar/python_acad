# %% [markdown]
# Exercise 2.2

# %%
width=17
height=12.0
delimiter='.'

width/2
# Out:
# 8.5

# %%
type(width/2)
# Out:
# float

# %%
width/2.0
# Out:
# 8.5

# %%
type(width/2.0)
# Out:
# float

# %%
height/3
# Out:
# 4.0

# %%
type(height/3)
# Out:
# float

# %%
1+2*5
# Out:
# 11

# %%
type(1+2*5)
# Out:
# int

# %%
delimiter*5
# Out:
# '.....'

# %%
type(delimiter*5)
# Out:
# str

# %% [markdown]
# Exercise 2.3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
r=5
v=(4/3)*(22/7)*r*r*r
print(v)
# Out:
# 523.8095238095237

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
cover_price=24.95
store_cost=cover_price-(0.4*cover_price)
shipping_total=3+(0.75*59)
wholesale_cost=shipping_total+(60*store_cost)
print(wholesale_cost)
# Out:
# 945.4499999999999

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
seconds=(2*((8*60)+15))+(3*((7*60)+12))
minutes=int(seconds/60)
seconds=seconds%60
print(minutes)
print(seconds)
# Out:
# 38
# 6

# %% [markdown]
# Total running time is 38 minutes and 6 seconds.
# Hence, the time of reaching home is 6:52 + 38 minutes 6 seconds
# = 7:30 am
